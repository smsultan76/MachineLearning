# %% [markdown]
# <a href="https://colab.research.google.com/github/smsultan76/MachineLearning/blob/main/Lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('hello')
# Out:
# hello

# %%
a = 12

# %%
print(a)
# Out:
# 12
